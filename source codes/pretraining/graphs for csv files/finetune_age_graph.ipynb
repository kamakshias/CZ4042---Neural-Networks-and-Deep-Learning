# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pyl

# %%
df_fine = pd.read_csv('/content/finetuned_csvlog_age_final.csv')

# %%
def df_to_list(df):
    data2=[]
    for i in range(len(df)):
        data2.append(df['val_accuracy'][i])
    return data2

def df_to_list_2(df):
    data2=[]
    for i in range(len(df)):
        data2.append(df['accuracy'][i])
    return data2

# %%
df_fine_val=df_fine_train=[]
df_fine_val=df_to_list(df_fine)
df_fine_train=df_to_list_2(df_fine)

# %%
df_list=[]
df_list.append(df_fine_l)

# %%
pyl.plot(df_fine_val)
pyl.plot(df_fine_train)
pyl.title('Finetuned age model accuracy')
pyl.ylabel('accuracy')
pyl.xlabel('epoch')
pyl.legend(['val', 'train'], loc='upper left')
